# %%
import sys
sys.version
# Out:
# '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]'

# %%
# Imports
from __future__ import division
import numpy as np
import os
import glob
from PIL import Image, ImageOps
from random import *
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Lambda, ELU, Activation, BatchNormalization
from keras.layers.convolutional import Convolution2D, Cropping2D, ZeroPadding2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop

# %%
# Create a list of images and scribes from the facsimile image files
import json

json_file = open('../../150-inscriptions.js')
inscriptions = json.load(json_file)["inscriptions"]

scribes = []
imgs = []
for inscription in inscriptions:
    if not inscription["scribe"] or not inscription["facsimileImages"]:
        continue
        
    scribes += [inscription["scribe"]]
    imgs += [inscription["facsimileImages"][0]]
img_files = np.asarray(imgs)
img_targets = np.asarray(scribes)
print(img_files,img_targets)

# %%
# Create a list of images and scribes from the individual letter images
# concatenated into 12 character strips

import os
rootdir = 'letterimages'

# the output directory for our strips
strip_prefix = 'stripsof'
if not os.path.exists(strip_prefix + rootdir):
    os.makedirs(strip_prefix + rootdir)

def createStripFromLetters(letters):
    imgs = [ImageOps.grayscale(Image.open(l)) for l in letters]
    sizes = [i.size for i in imgs]
    strip_height = max(h for _,h in sizes)
    strip_width = sum(w for w,_ in sizes)
    
    strip = Image.new('RGB', (strip_width, strip_height))
    cw = 0
    for im,(w,h) in zip(imgs, sizes):
        strip.paste(im=im, box=(cw, 0))
        cw += w
        
    # Resize so height = 113 while keeping aspect ratio
    new_strip_height = 113
    height_fac = new_strip_height / strip_height
    new_width = int(strip_width * height_fac)
    size = new_width, new_strip_height
    return strip.resize((size), Image.ANTIALIAS)

scribes = []
imgs = []
strip_size = 12
for subdir, dirs, files in os.walk(rootdir):
    if subdir == rootdir:
        continue
    for offset in range(0, len(files), strip_size):
        letters = [os.path.join(subdir,f) for f in files[offset:offset+strip_size]]
        r = createStripFromLetters(letters)

        if not os.path.exists(strip_prefix + subdir):
            os.makedirs(strip_prefix + subdir)
        
        strip_name = strip_prefix + os.path.join(subdir, str(offset)) + '.jpg'
        r.save(open(strip_name, 'w'))
        
        scribe = subdir.split('/')[-1]
        scribes += [scribe]
        imgs += [strip_name]
        
img_files = np.asarray(imgs)
img_targets = np.asarray(scribes)

# %%
# Visualizing the data
for filename in img_files[:3]:
    img=mpimg.imread(filename)
    plt.figure(figsize=(5,5))
    plt.imshow(img, cmap ='gray')

# %%
# Label Encode writer names for one hot encoding later
encoder = LabelEncoder()
encoder.fit(img_targets)
encoded_Y = encoder.transform(img_targets)

print(img_files[:5], img_targets[:5], encoded_Y[:5])
# Out:
# ['stripsofletterimages/HT Wa Scribe 94/0.jpg'
#  'stripsofletterimages/KH Wc Scribe 56/0.jpg'
#  'stripsofletterimages/HT Wa Scribe 89/0.jpg'
#  'stripsofletterimages/HT Wa Scribe 34/0.jpg'
#  'stripsofletterimages/HT Wa Scribe 69/0.jpg'] ['HT Wa Scribe 94' 'KH Wc Scribe 56' 'HT Wa Scribe 89' 'HT Wa Scribe 34'
#  'HT Wa Scribe 69'] [70 89 65 27 45]

# %%
#split into test train and validation in ratio 4:1:1

from sklearn.model_selection import train_test_split
train_files, rem_files, train_targets, rem_targets = train_test_split(
        img_files, encoded_Y, train_size=0.66, random_state=52, shuffle= True)

validation_files, test_files, validation_targets, test_targets = train_test_split(
        rem_files, rem_targets, train_size=0.5, random_state=22, shuffle=True)

print(train_files.shape, validation_files.shape, test_files.shape)
print(train_targets.shape, validation_targets.shape, test_targets.shape)
# Out:
# (250,) (65,) (65,)
# (250,) (65,) (65,)

# %%
# Generator function for generating random crops from each sentence

# # Now create generators for randomly cropping 113x113 patches from these images

batch_size = 16
num_classes = 100

# Start with train generator shared in the class and add image augmentations
def generate_data(samples, target_files,  batch_size=batch_size, factor = 0.1 ):
    num_samples = len(samples)
    from sklearn.utils import shuffle
    while 1: # Loop forever so the generator never terminates
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset+batch_size]
            batch_targets = target_files[offset:offset+batch_size]

            images = []
            targets = []
            for i in range(len(batch_samples)):
                batch_sample = batch_samples[i]
                batch_target = batch_targets[i]

                im = ImageOps.grayscale(Image.open(batch_sample))
                #im = Image.open(batch_sample).convert('RGB')
                cur_width = im.size[0]
                cur_height = im.size[1]

                avail_x_points = list(range(0, cur_width - 113 ))# total x start points are from 0 to width -113

                # Pick random x%
                pick_num = int(len(avail_x_points)*factor)
                # Now pick
                random_startx = sample(avail_x_points,  pick_num)
                for startx in random_startx:
                    imcrop = im.crop((startx, 0, startx+113, 113))
                    images.append(np.asarray(imcrop))
                    targets.append(batch_target)
                    
            # trim image to only see section with road
            X_train = np.array(images)
            y_train = np.array(targets)

            #reshape X_train for feeding in later
            X_train = X_train.reshape(X_train.shape[0], 113, 113, 1)
            #convert to float and normalize
            X_train = X_train.astype('float32')
            X_train /= 255

            #One hot encode y
            y_train = to_categorical(y_train, num_classes)

            yield tuple(shuffle(X_train, y_train))

# %%
# Generate data for training and validation
train_generator = generate_data(train_files, train_targets, batch_size=batch_size, factor = 0.3)
validation_generator = generate_data(validation_files, validation_targets, batch_size=batch_size, factor = 0.3)
test_generator = generate_data(test_files, test_targets, batch_size=batch_size, factor = 0.1)

# %%
# Build a neural network in Keras

# Function to resize image to 56x56
def resize_image(image):
    import tensorflow as tf
    return tf.image.resize(image,[56,56])

# Function to resize image to 64x64
row, col, ch = 113, 113, 1

model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(row, col, ch)))

# Resise data within the neural network
model.add(Lambda(resize_image))  #resize images to allow for easy computation

# CNN model - Building the model suggested in paper

model.add(Convolution2D(filters= 32, kernel_size =(5,5), strides= (2,2), padding='same', name='conv1')) #96
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool1'))

model.add(Convolution2D(filters= 64, kernel_size =(3,3), strides= (1,1), padding='same', name='conv2'))  #256
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool2'))

model.add(Convolution2D(filters= 128, kernel_size =(3,3), strides= (1,1), padding='same', name='conv3'))  #256
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool3'))


model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(512, name='dense1'))  #1024
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256, name='dense2'))  #1024
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes,name='output'))
model.add(Activation('softmax'))  #softmax since output is within 50 classes

model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# zero_padding2d_88 (ZeroPaddi (None, 115, 115, 1)       0
# _________________________________________________________________
# lambda_61 (Lambda)           (None, 56, 56, 1)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 28, 28, 32)        832
# _________________________________________________________________
# activation_510 (Activation)  (None, 28, 28, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 14, 14, 64)        18496
# _________________________________________________________________
# activation_511 (Activation)  (None, 14, 14, 64)        0
# ...

# %%
# Train the model 

nb_epoch = 8

samples_per_epoch = 1502
nb_val_samples = 642


#save every model using Keras checkpoint
from keras.callbacks import ModelCheckpoint
filepath="checkpoint2/check-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath= filepath, verbose=1, save_best_only=False)
callbacks_list = [checkpoint]

#Model fit generator
history_object = model.fit(train_generator, steps_per_epoch= samples_per_epoch,
                                     validation_data=validation_generator,
                                     validation_steps=nb_val_samples, epochs=nb_epoch, verbose=1, callbacks=callbacks_list)
# Out:
# Epoch 1/8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-457-3e7f959360f5> in <module>
#      14
#      15 #Model fit generator
# ---> 16 history_object = model.fit(train_generator, steps_per_epoch= samples_per_epoch,
#      17                                      validation_data=(validation_generator),
#      18                                      validation_steps=nb_val_samples, epochs=nb_epoch, verbose=1, callbacks=callbacks_list)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# ...

# %%
# Load save model and use for prediction on test set
model.load_weights('checkpoint2/check-08-7.6340.hdf5')
scores = model.evaluate_generator(test_generator,842) 
print("Accuracy = ", scores[1])
# Out:
# Accuracy =  0.18037453293800354
