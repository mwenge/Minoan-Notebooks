# %%
# Classifications 

classifications = {
    # Assumed to be a distribution of an implied commodity to the entities.
    "Entity List" : {
        "Description": "List of entities with values assigned",
        "Tablets": ["HT119", "ZA14","HT11a","HT108","HT146","HT25a",
                   "HT29","HT3","HT39","HT63","HT8b","HT98a","HT99b","ZA20","ZA4a","ZA5b",
                   "ZA7a","ZA10a","PE2"],
        "HasTransactionSign": ["HT63"],
        "ambiguity": ["HT3","HT8b","ZA20","ZA4a","PE2","HT146","HT25a",
                     "HT29","HT39", "HT63","HT98a","ZA7a"],
        "variations": {
            "HT63": "Contains reference to commodity in headwords",
            "HT119": "Actually a mixed entity/commodity list.",
        }
    },
    "Commodity List" : {
        "Description": "List of commodities with values assigned",
        "Tablets": ["HT130","HT24b","TY2","HT127b",],
        "variations": {
            "HT127b": "No interpretation, probably a disbursement list with entity missing",
        }
    },
    "Disbursement List" : {
        "Description": """A Disbursement List consists of an entity followed """
                       """by a Commodity List. Tablets usually contain more than one Disbursement List.""",
        "Tablets": ["HT121","HT125b", "HT12", "HT18","HT100","HT101","HT105","HT106","HT108","HT116b",
                   "HT123+124a","HT129","HT131a","HT131b","HT132","HT133","ARKH3a", "ARKH3b","HT2",
                   "HT21","HT23a","HT23b","HT27b","HT30","HT32","HT40","HT42+59","HT44a",
                   "HT58","HT91","HT92","HT94a","ZA1a","ZA6b","ZA9","ZA15b","KH9","KH6","KH7a","KH7b",
                   "TY3a","TY3b","ARKH5","ARKH3a","ARKH3b","KH11","HT14","KNZb35","ZA6a",
                   "HT125a","KH4","HT24a","HT36",],
        "HasTransactionSign": ["HT133","HT21","HT32","HT40","HT42+59","HT91","HT92","ZA1a","KH11",
                              "HT14","HT36"],
        "ambiguity": ["HT27b","HT30","HT58","ZA9","KH6","KH7a","KH7b","ARKH3a","ARKH3b","KH4","HT105"],
        "variations": {
            "HT36": "DU-ZU TELA instead of DU-ZU-WA allows this to be a distribution list",
            "HT105": "Ignoring lacuna and assuming KA-PA receives VIR in lines 1-2",
            "HT125a": "Only disbursement at end is included - lacuna in rest doesn't allow interpretation.",
        }
    },
    "Single Entity Heading and Disbursement List" : {
        "Description": """A single Entity (sometimes with a transaction sign) followed by """
                        """one or more Disbursement Lists.""",
        "Tablets": ["HT114a","HT116a","HT120", "HT125b","HT128a","HT28a","HT28b","HT31","HT33","HT35","HT43",
                   "HT91","HT96b","HT99a","ZA11a","PE1","HT11b","HT16","HT20","ZA11b",],
        "HasTransactionSign": ["HT116a","HT128a","HT35","HT43","HT96b","ZA11a","ZA11b",],
        "ambiguity": ["HT33",],
        "variations": {
            "HT16": """Mix of entity and commodities in disbursement. Interpret the entity as a disursement"""
                    """ with an implied commodity.""",
            "HT20": """Mix of entity and commodities in disbursement. Interpret the entity as a disursement"""
                    """ with an implied commodity.""",
            "PE1": """Interpreted as a disbursement list, with multiple entities receiving the same disubrsement.""",
        }
    },
    "Multiple Entity Heading and Disbursement List" : {
        "Description": """Multiple Entities (sometimes with a transaction sign) followed by """
                        """one or more Disbursement Lists.""",
        "Tablets": ["HT34","HT90","KH5","KH7a","ZA18a"],
        "HasTransactionSign": [],
        "ambiguity": ["HT34","ZA18a"],
        "variations": {
            "KH7a": "Treating TA-TA as a transaction sign.",
            "HT20": """Mix of entity and commodities in disbursement. Interpret the entity as a disursement"""
                    """ with an implied commodity.""",
        }
    },
    "Single Entity Heading and Entity List" : {
        "Description": """A single Entity (sometimes with a transaction sign) followed by """
                        """one or more Entity Lists.""",
        "Tablets": ["HT1","HT10a","HT10b","HT15","HT20","HT13", "HT104","HT115a","HT122a",
                   "HT122b", "HT123+124b","HT126a","HT7a","HT7b","HT85b","HT9b","HT94b","HT95a",
                   "HT95b","ZA5a","ZA15a","HT26a"],
        "HasTransactionSign": ["HT13", "HT104", "HT115a","HT122b","HT126a"],
        "ambiguity" : ["HT122a","HT104","HT122b","HT126a"],
        "variations": {
            "HT26a": "Contains reference to commodity in headwords",
            "HT13": "Contains reference to commodity in headwords",
            "HT115a": "Contains reference to commodity in headwords",
            "HT7a": "Contains reference to commodity in headwords",
            "HT95a": "Contains reference to commodity in headwords",
            "ZA5a": "Contains reference to commodity in headwords",
            "ZA15a": "Contains reference to commodity in headwords",
            "HT122b": "Contains reference to commodity in headwords",
            "HT123+124b": "Complex pattern - not included in network yet.",
        }
    },
    "Multiple Entity Heading and Entity List" : {
        "Description": """Multiple Entities (sometimes with a transaction sign) followed by """
                        """one or more Entity Lists.""",
        "Tablets": ["HT117a","HT17","HT85a","HT87","HT88","HT9a"],
        "ambiguity": ["HT85a"],
        "variations": {
            "HT88": "Contains reference to commodity in headwords",
            "HT9a": "Contains reference to commodity in headwords",
        }
    },
    "Single Entity Heading and Hybrid Commodity/Entity List" : {
        "Description": """A single Entity (sometimes with a transaction sign) followed by """
                       """a mixed Commodity/Entity list.""",
        "Tablets": ["HT19","HT103","HT110a","HT26b","HT27a","HT6a","HT6b","HT62+73",
                   "HT8a","HT89","HT93a","HT97a","ZA8","KH88","ZA10b",],
        "HasTransactionSign": ["HT62+73","HT97a","HT89"],
        "ambiguity": ["HT26b","HT62+73",],
        "variations": {
            "HT89": "Interpret the entities as commodities so it becomes a Disbursement List. Trailing commodity list creates ambiguity.",
            "HT93a": "A complex text not possible yet to establish a transaction pattern.",
            "HT103": "Transaction pattern not clear",
            "HT110a": "Not included in network. Like HT89 has trailing commodity list which creates ambiguity.",
            "ZA10b": "Interpret the VIN as modifying the implied commodity so that this becomes a kind of disbursement list.",
        }
    },
    # Two entities in the heading implies one is giving to all the others in the list.
    # More than two is not clear what the intention is.
    # A hybrid list can suggest that the commodity carries over to the next entity in the list.
    "Multiple Entity Heading and Hybrid Commodity/Entity List" : {
        "Description": """Multiple Entities (sometimes with a transaction sign) followed by """
                       """a mixed Commodity/Entity list.""",
        "Tablets": ["ARKH2","HT102","HT115b","HT140","HT6a","HT6b","HT86a","HT86b","HT96a"],
        "HasTransactionSign": ["ARKH2","HT6a"]
    },
}

# %%
import json

json_file = open('CommodityOrderData/150-inscriptions.js')
inscriptions = json.load(json_file)["inscriptions"]
inscriptions_by_name = {i["name"]: i for i in inscriptions}

# %%
# Create a dictionary with the transliterated word-list for each tablet in the classification
tablet_detail = {}
for c,v in classifications.items():
    for t in v["Tablets"]:
        words = [w for w in inscriptions_by_name[t]["words"]
                 if w != '\n']
        t_words = [w for w in inscriptions_by_name[t]["transliteratedWords"]
                   if w != '\n']
        f_words = []
        for i, w in enumerate(t_words):
            if words[i].startswith("𐝫"):
                w = "]" + w
            if words[i].endswith("𐝫"):
                w = w + "["
            f_words += [w.replace("\U0001076b","")]
        tablet_detail[t] = f_words

# %%
for c,v in classifications.items():
    print(c)
    print("Description: " + v["Description"])
    for t in v["Tablets"]:
        d = ' '.join(tablet_detail[t])
        s = f'{t}: {d}'
        print(s)
    print()
# Out:
# Entity List
# Description: List of entities with values assigned
# HT119: *327 34 VIR+[?] 67 RI-MI-SI 13 KO-JA 10 KU-PA₃-NA-TU 7 TI 7 JA-*345 10 *306-TU 2 *327-JU 8 KU-RO 160
# ZA14: ME-KI-DI 1 *21F-*118 1 PU-NI-KA-*363 3 QA-TI-JU 8 KU-PI 1 TU-MI-TI-ZA-SE 45[ PA-NU-QE 2 JA-WI[ ][ ][
# HT11a: A-RU-RA[ 𐄁 ]3 KA-RO-NA 2 *322-RI 1 KU-RO 10 A-SU-JA 1 VIR+[?]-I 3 TA₂ 15
# HT108: KI-RE-TA-NA VIR+[?] 1 GRA+H 70 — DI-NA-RO 2 DU-SU-NI 5[ 𐄁 ]RA₂-TI 10 JU[ ][
# HT127b: ][ ][ ]NE 13[ KU-RO *307 156 KU 72 VIR+*313c 24 KI+MU 15 *301 11 KI+MU 14 KU-RO 291
# HT146: ][ ]QE[ ]30 RI-*305 30 MA 30 RI-KA-TA 30
# HT25a: ][ ]1 DI-NA-U[ ]RU-NI 1 U-RE-WI 1 DI-NA-U 1 A-RI-NI-TA 1 TU-QE-NU[ ]ZU-JU-PU₂ 1 DU-RU-WI[ ]I-KI-RA 1 PA 1
# HT29: RU-MA-TA 2[ 𐄁 1 PA-JA-RE 2[ ]DI-JA-I 2 SA-*323-MI 1 𐄁 ]KI-TA 2 A-RE-DA-I 2 KA-DU-MA-NE 1
# HT3: ][ ]MA[ ]DI-NA[ 2 QE-RA₂-JA[ ]2 DI 2[ ]4 MU-RU 1 RU[ ]SI-TU-RA₂-RE 5 DI[ ]KU-PA₃-NU 3[ ]MA-DI 2[ DA[
# HT39: TA-I-AROM 10[ ]KU-RE-JU 8 KU[ ]SA-MA-TI 10 KU-RE[ ]KU-RO *414+A 100 ]KU+[ ] 2[ DU+[ ][ ][
# HT63: *305 𐄁 TE 1 KA-TI 1 SU-PU₂[ ]ZU 2 ][ ][
# HT8b: SU-PU₂-*188 1 — 5 PA₃-*188 2 QA-*310-I 1 ³⁄₈ KA-PA ¹⁄₂ PA-JA-RE 1 ¹⁄₈ *86+'*188' ¹⁄₂ ¹⁄₂
# HT98a: ][ ]DE 1[ ]TU 1 TA-NA-TI ³⁄₄ DI-RE-DI-NA ¹⁄₂ TE-*301 ³⁄₄ RO-KE ¹⁄₂ KA-RI-*310-I ¹⁄₄
# HT99b: SI+SE-NI 6 DA-SI-*118 2 ZU-DU 1 RU-MA-TA 1
# ZA20: ][ ]DU-RE-ZA-SE[ ]MI[ 𐄁 4 SI-TE-TU 1 SI-TU 6 TE-AROM 12 RU-MA-TA-SE 3 KU-RA 130 ][
# ZA4a: ][ ][ ]E[ ]PI[ 𐄁 ]SE[ ]5 JA-TO-JA[ ]3[ A-TI-RU 4 JA-PA 1[ 𐄁 ]TU-ME-SE 18 QE-SI-ZU-E 4 *28B-NU-MA-RE 13 SI-PI-KI 5 E-*82 50 KA-DI 3
# ZA5b: *28B-NU-MA-RE 20 SI-PI-KI 1 ¹⁄₂ MA-KA-I-TA 3
# ZA7a: U-JU 5 A-RA-TU 4 A-RE-TU-MI[ ][
# ZA10a: TA-NA-TE 2 PA[ 1 A-KU-MI-NA 1 A-TA-NA-TE 1 A-MI-DA-U 1 A-DU-KU-MI-NA 1 DA-I-PI-TA 1 DU-RE-ZA-SE 2
# ZA10b: WA-*362 2 DU-RE-ZA-SE *131B 5 U-*49 6 MA-ZA 5 MA-KI-DE-TE 5 SA-MA 5 A-DE 4 A-MI-TA 3 RA₂-RO-RE 2 PA-JA-RE 1 KA-KU-NE-TE ¹⁄₂ TA 2 DU 1[
# PE2: ][ 3 ¹⁄₃ RU-PI-*305-MI 1 ¹⁄₈ A-*325-ZA ¹⁄₄ A-RI-PA ¹⁄₄ QA-QA-DA ¹⁄₂ TO-ME ¹⁄₃ TO-*49-RE 1 ][
#
# Commodity List
# Description: List of commodities with values assigned
# HT130: ][ ]SI 3 SA-RA₂ CYP[ ][ ]RA₂[ ]KU-RO[ — SI-CYP 8 NI 6 VIN 3
# HT24b: ]*118 1 ³⁄₄ SI+ME-KI-*118 1 ³⁄₄ *539-*118 1
# TY2: *309B-*34-PU-PI 500 *309[ 290 *309B-KI-PU 50 *309-DA-PU[ 10 PA-DA-RU *309-JU-KI 100 *309-RI-JU[ *309[ ]6 VIR+[?] 82 *309C-DA-JU 17[ *309C-RU-KA 30 *309-RI-WA-JU 160 ]*309B-RI-JU 250 *309B[ ][
#
# Disbursement List
# Description: List of 1 or more entities with commodities listed against them
# HT121: KI-RI-TA₂ OLE+QE+DI 10 SA-RA₂ GRA 5 OLE 4 NI 2 VIN 3 *23M 3
# HT125b: ][ ][ ]20 ]RE-TA₂ GRA+PA 20 GRA+F 7 ¹⁄₂ *304 10 NI 23
# HT12: QA-TI-DA-TE 𐄁 OLE+DI 5 *304 5 QE-TU-NE 𐄁 QA2+[?]+PU 1 E 30 *560 𐄁 *118 5 CYP+E 3 NI 1 QA2+[?]+PU+RE ¹⁄₁₆ DA-I 50
# HT18: PA-SE GRA+QE 20 OLE+KI 2 *304 3 SA-RA₂ GRA 10 NI 10
# HT100: ]VIR+KA 58 *304+PA[ ][ TI+A 12 KI 2 *305 5 VIR+*313a 16 KU-RO 97 SA-RA₂ CYP 5 ¹⁄₄ NI 2 double mina VIN 2 ¹⁄₂ OLE+U 2 ≈ ¹⁄₆ OLE+MI 3 OLE+NE ³⁄₄
# HT101: ZU-*22F-DI GRA+QE 40 OLE+U 8 OLE+MI 8 OLE+KI 2 SA-RA₂ GRA 41 OLE 10 DI+QE 3 KU-PA₃[ ]OLE+U 2 — ]20 *304 3 OLE+KI 2[ ]3 OLIV 1 ¹⁄₄ *OLIV+TU 1
# HT105: KA-PA[ ][ ]VIR+[?] 234 SA-RA₂ 𐄁 VIR+[?] 235
# HT106: MI-NU-TE CYP 6[ SI 5 ¹⁄₂ SI 1 — DA[ 𐄁 8[ ]SI 3[ ][
# HT108: KI-RE-TA-NA VIR+[?] 1 GRA+H 70 — DI-NA-RO 2 DU-SU-NI 5[ 𐄁 ]RA₂-TI 10 JU[ ][
# HT116b: KU-RO GRA 100[ *304 15 OLE 17
# HT123+124a: KI-TA-I 𐄁 OLIV 31 *308 8 ¹⁄₄ KI-RO 1 .3 PU-VIN OLIV 31 ¹⁄₂ *308 8 ³⁄₄ KI-RO .3 SA-RU OLIV 16 *308 4 ≈ ¹⁄₆[ ]KI-RO ³⁄₄ DA-TU OLIV 15 *308 4 ¹⁄₄ KI-RO ³⁄₄ KU-RO OLIV 93 ¹⁄₂ *308 𐄁 KU-RO ]25 ≈ ¹⁄₆ KI-RO 6[
# HT129: KI-RE-TA₂ GRA 33 𐝆𐝁 *304 10 NI 22 TU-*21F-RI-NA GRA 40 ¹⁄₂ OLE+DI 1[ ]OLE+KI 6 ]OLE[ ][
# HT131a: ][ ]NI 62 KU[ ]353 I-QA-*118 GRA 58[ ]OLE 12 ¹⁄₂ *304 12 ³⁄₄
# HT131b: ][ ]NI 30[ ]OLIV 2 VIN+SA[ — PO-TO-KU-RO ]451 ¹⁄₂[
# HT132: A-SE 𐄁 *904 5 QA-RE-TO 𐄁 *22F 27 PA₃ 𐄁 *305 1[ ][ ][
# HT133: A-DU 𐄁 TE GRA+DA 55
# ARKH3a: ]KA-NE GRA[ ]¹⁄₅ OLIV 3 ¹⁄₅ *131B 2[ ]2 *317 2 ][ ]KI-NU GRA 13[ ]TE 2 *317 2 *312 2[ ]KU 3
# ARKH3b: ]JA-PI GRA 6[ ]PI-*314 GRA 1[ OLE[ ][ ]2 OLE 4 ]VIN 1 ][
# HT2: A-KA-RU 𐄁 OLE+U 20[ ]OLE+A 17 OLE+E 3[ ]KI-RE-TA-NA OLE+U 54[ ]OLE+A 47 1
# HT21: PI-TA-KA-SE 𐄁 TE 𐄁 GRA 161 OLE+U 11 OLE+E 3 ³⁄₄ *304 7 ³⁄₄ OLIV 1 ¹⁄₄
# HT20: PA-RO-SU 𐄁 KU-MA-JU ¹⁄₄ QE-KU-RE 𐄁 DI ¹⁄₂ *21M ¹⁄₈ SA-RE-JU ¹⁄₈ WA ¹⁄₄ *188+KU ¹⁄₂
# HT23a: KA-NA 𐄁 CYP ¹⁄₃ *308 ≈ ¹⁄₆ OLE+NE ≈ ¹⁄₆ OLE+TU ≈ ¹⁄₆ OLE+RI ≈ ¹⁄₆ MI+JA+RU ≈ ¹⁄₆ VIN 10 QA2+[?]+RE 10 QA2+[?]+RE+PU 10 E 17 *21F-RI-TU-QA ¹⁄₁₆ SA-SA-ME ¹⁄₁₆ SI+ME 10 KO-RU 1
# HT23b: NI-RA CYP ¹⁄₃ OLE[ ¹⁄₃ MI+JA+RU ]MU[ QA2+[?]+PU[ QA2+[?]+RE 1 ][ E 7[ ][
# HT27b: ]MI-DA 𐄁 VIN+WA 𐄁 SA 7 ]VIN 𐄁 GRA 𐄁 SA 1 RE 14 VIN 𐄁 SI 𐄁 ][ PA-SE 𐄁 VIN+WA 𐄁 SA 4 RE 70 VIN[ 𐄁 ]GRA 𐄁 SA 4 RE[ 40
# HT30: SI 4 SA-RA₂ CYP[ ]14 ¹⁄₂ NI 7 ¹⁄₅ VIN 8 ¹⁄₂ OLE+TA 𐝓 QA2+[?]+PU ¹⁄₅ SA-RA-RA ¹⁄₂ *23M 1 KI-RO 𐄁 CYP 8 NI 𐝓 VIN ¹⁄₂ *23M 1[ ]¹⁄₅ OLE+TA ¹⁄₅ ][
# HT32: *307 SA-RA₂ 𐄁 *308 ¹⁄₂ OLE+NE 𐝆𐝇 QA2+[?]+PU 1 ¹⁄₁₆ QA2+[?]+RE 1 MI+JA+RU 1 SU-RE 𐄁 108 DI 65 OLE+NE[ ]RE 104 DI 53
# HT40: NU-DU-*331 𐄁 TE 𐄁 GRA 207 KI-DA-TA 𐄁 GRA[ 134 KU-RO[ KU[ ][
# HT42+59: ]TA 𐄁 SI+SE 𐄁 TE 𐄁 OLE+KI 8 OLE+U ]7 SA-RO OLE+KI 8 OLE+U 2[ ]2 KU[ ]OLE[ ][ OLE+MI 2 SU-DU[ ]RE-TU OLE+KI ]³⁄₄ OLE+U[
# HT44a: I-QA-*118 𐄁 GRA[ OLE+KI 3 OLE+U 5[ OLE+RA 5 OLIV 1[ ]NI 1 VIN[ ][
# HT58: QE-TI-RA-DU 𐄁 VIR+[?][ OLE+U 19 OLE+MI[ ]OLE+E 3 OLIV 41 ]U-KI[ ][
# HT91: I-KA 𐄁 *326 𐄁 GRA .3 *304 ≈ ¹⁄₆ 𐄁 OLE+KI ≈ ¹⁄₆ OLE+U ≈ ¹⁄₆ OLE+MI ≈ ¹⁄₆ OLIV ≈ ¹⁄₆ NI ≈ ¹⁄₆ VIN ≈ ¹⁄₆ E 5 TE-RI 𐄁 OLE+MI ≈ ¹⁄₆ E 3[ ][
# HT92: TE 𐄁 A-DU 𐄁 GRA 680 *304 12
# HT94a: KA-PA VIR+[?] 62 *86 20 TI+A 7 VIR+*313b 18 TA 4 KU-RO 110 SA-RA₂ CYP 5 NI 3 ≈ ¹⁄₆ ]2 *318-*306 11 CYP double mina NI double mina ]14 ¹⁄₂ NI ¹⁄₅
# ZA1a: *516 𐄁 KI-RE-ZA 𐄁 NI 42 ¹⁄₂ ZA 5 ][
# ZA6b: I-KU-JU-TI-*28B GRA+PA 50 ¹⁄₄ VIN+RA 40 VIN+KA 10 *312-TA₂ GRA+PA 40[ ]20 — PA-ZA[ ]I-MA[
# ZA9: ]NU-TI 𐄁 ZA[ ]RA QI+SI 5 ][ ]RO-SI-RA[ QI+SI 4 A-TA-NA[ 𐄁 ][ QI+SI 2 𐄁 ]MA-JU *22F 2 WI-RA-RE-MI-TE *22F 1
# ZA15b: KA-DI 𐄁 VIN 3 — KU-RO 𐄁 VIN 78 VIN+RA 17
# KH9: A-SI-SU-PO-A 𐄁 VIR+*307[ ]¹⁄₁₆ NI 𐝃𐝁 MI[ ]I-SI 𐄁 CYP+D ¹⁄₂[ ]2 CYP ¹⁄₄ VIN[ ]CYP 𐝃𐝉[ ].3 SI+TA2-*304 1[
# KH6: ]CYP+D ¹⁄₂ DI-SI[ ]TE-NU-RE[ ]KI-SA-NE CYP+D ¹⁄₂ *347[ ]CYP[ ¹⁄₂ RI-TA-JE CYP+D[ ]*21M 1 CYP+D ¹⁄₂ MU 1 PA[ ]RE 𐄁 *334 1 CYP+D ¹⁄₂ PI-SA[ ]CYP+D ¹⁄₂ AU-RE-TE 𐄁 *306 1 ]8 CYP 2 𐝆𐝁
# KH7a: ]NE[ 𐄁 ]KI *334 4 CYP+D 1[ ]I CYP+E ¹⁄₁₆ E-NA-SI 𐄁 VIR+*313b 10 CYP+D ¹⁄₂ I-JA-PA-ME 𐄁 TA-TA 𐄁 QA-TI-KI VIR+*313b 4 CYP+D ¹⁄₃ SE-*305 𐄁 KU[ 𐄁 ]KO-E VIR+*313b ]18 CYP+D 1 𐝕𐝉[ ]𐝁𐝌 ][
# KH7b: ][ — U-TA-I-SE CYP+D ¹⁄₂[ ]PA-NA-TU CYP+D ¹⁄₂ *304+PA 1 SI 14 CYP+K 2
# TY3a: ]ZA-*321 OLE+KI 15 ¹⁄₄ OLE+U 22 NE-KI 5 OLE+QIf 3 ¹⁄₂ OLE+MI[ OLE+U 7 ¹⁄₂ — A-DU[ 𐄁 ][ OLE+KI 51 OLE+KI+U 2 ¹⁄₅ OLE+KI+ME 1 OLE+QIf 4 ¹⁄₂ ]OLIV[ 4[ — A-DA OLE+U 21 OLE+MI 2[ ]KO-A-DU-WA OLE[ 7 ¹⁄₅ — A-KU-TU-*361[ ]KI 5 OLE+TU 1 —
# TY3b: KI-RI-SI OLE+MI 6[ — PI-KU-ZU OLE+KI 4 OLE+MI 11[ ]OLE+NE 2[ — PA-OLE+MI[ ]220[
# ARKH5: A-DU-NI-TA-NA 41[ ]7 A-DA-RO GRA 40[ *131B 6 A[ ][
# ARKH3a: ]KA-NE GRA[ ]¹⁄₅ OLIV 3 ¹⁄₅ *131B 2[ ]2 *317 2 ][ ]KI-NU GRA 13[ ]TE 2 *317 2 *312 2[ ]KU 3
# ARKH3b: ]JA-PI GRA 6[ ]PI-*314 GRA 1[ OLE[ ][ ]2 OLE 4 ]VIN 1 ][
#
# Disbursement List with another entity
# Description: List of 1 or more entities with commodities listed against them preceded by 1 other entity
# HT114a: KI-RI-TA₂ SA-RA₂ GRA 10 OLE 7 NI 1 VIN 1 *23M 3
# HT116a: U-TA-RO 𐄁 TE 𐄁 KU-PA-JA GRA 16 PU-RA₂ 𐄁 GRA 40 OLE+DI 5 SI+SE GRA 16 OLE+KI 1 OLE+MI 6 OLIV 3 PI-*34-TE GRA 5 OLE[ 5 OLE+MI 1 *OLIV+TU 2 SI-KI-NE GRA 12 *304 12 QA-NU-MA GRA 20 *304 3
# HT120: DA-QE-RA 𐄁 DA-ME GRA+K+L 74 GRA+PA 62 𐝆𐝀 DA-U-*49 𐄁 I-GRA+PA 20 KI-RE-TA-NA GRA+B 60 GRA+PA 48 PA-I-TO 3 ¹⁄₅
# HT125b: ][ ][ ]20 ]RE-TA₂ GRA+PA 20 GRA+F 7 ¹⁄₂ *304 10 NI 23
# HT128a: *326 𐄁 PA-RA TU-RU-NU-SE-ME GRA[ 10 WA-TU-MA-RE GRA+KU 12[ ]MI-TA GRA+PA ¹⁄₂[ GRA+KU 6 DI[ GRA+KU 4 MA-RI[ ][
# HT28a: A-SI-JA-KA 𐄁 JA-*21F 𐄁 GRA+QE 5 OLE+U 2 OLE+KI ¹⁄₂ OLE+MI 1 OLE+TU 𐝉 SA-RA₂ OLE+DI 1 NI 2 VIN 3 VIR+KA-VIN 6 A-RU-DA-RA GRA 5 *304 2 OLE+DI 3 I-TA-JA OLE+DI 10
# HT28b: A-SI-JA-KA 𐄁 U-MI-NA-SI 𐄁 SA-RA₂ GRA 20 OLE+DI 5 NI 2 VIN 4 PU-RA₂ NI 6 JA-*21F VIN 6 WI-DI-NA OLE+DI 3 VIN 3 ¹⁄₄
# HT31: 𐄁 ]TI-SA 𐄁 PU-KO 𐄁 *410-VS ][ ]5 *815-QA-PA₃ 10 *415-VS-SU-PU 10 ]*416-VS-KA-RO-PA₃ 10 SA-JA-MA 30[ ]10 KI-DE-MA-*323-NA *815 400 *815-SU-PA₃-RA 300 *815-PA-TA-QE 3000
# HT33: SA-RA₂ 𐄁 *401+*304 QA2+[?]+RE+PU 1 ¹⁄₄ QA2+[?]+RE 𐝉𐝋[ ]3 E+KA 𐝃𐝉 MI+JA+KA ¹⁄₅ *305 90 *341+PI 100 PA3+QE 100
# HT35: TI-TI-KU 𐄁 *326 𐄁 I-KU-TA CYP 1 MI+JA+RU ¹⁄₃ OLE+RI ¹⁄₃ *308 ¹⁄₃ OLE+TA[ E 5 QA2+[?]+PU ¹⁄₁₆ VIN ¹⁄₅
# HT43: MA-SI-DU 𐄁 PA-*342-I 𐄁 I 𐄁 GRA+PA 5[
# HT91: I-KA 𐄁 *326 𐄁 GRA .3 *304 ≈ ¹⁄₆ 𐄁 OLE+KI ≈ ¹⁄₆ OLE+U ≈ ¹⁄₆ OLE+MI ≈ ¹⁄₆ OLIV ≈ ¹⁄₆ NI ≈ ¹⁄₆ VIN ≈ ¹⁄₆ E 5 TE-RI 𐄁 OLE+MI ≈ ¹⁄₆ E 3[ ][
# HT96b: A-PA-RA-NE 𐄁 QA-*118-RA-RE 𐄁 *516 𐄁 GRA 𐄁 40 ³⁄₄ OLE+U 4 NI 2 ¹⁄₁₆ ][
# HT99a: A-DU 𐄁 SA-RA₂ CYP 4[ NI 4[ VIN 1 ≈ ¹⁄₆ GRA+QE ][
# ZA11a: DI-DI-KO-RA-ME-TA₂ 𐄁 *516 𐄁 GRA+PA[ ]RA-MA-SI VIN ¹⁄₂[ ]E-KU-RU 2 ¹⁄₄ JU 𐝈𐝉 VIN ¹⁄₂ QE+GRA+PA 4 KU-PA 𐄁 GRA+PA 1[ PI-*310-A[ ]OLIV 2 ][
# KH11: A-DU[ 𐄁 ]ZA CYP ¹⁄₁₆ SU 3 CYP+E 𐝇𐝉 VIN ≈ ¹⁄₆ *306 4 CYP ¹⁄₃ *348-CYP 𐝇𐝉 A-TO-*349-TO-I CYP+E 3 NI 1 VIN 3 A-TA-*350 *301 1 *306 1 SI-CYP 𐝇𐝉
# KH7a: ]NE[ 𐄁 ]KI *334 4 CYP+D 1[ ]I CYP+E ¹⁄₁₆ E-NA-SI 𐄁 VIR+*313b 10 CYP+D ¹⁄₂ I-JA-PA-ME 𐄁 TA-TA 𐄁 QA-TI-KI VIR+*313b 4 CYP+D ¹⁄₃ SE-*305 𐄁 KU[ 𐄁 ]KO-E VIR+*313b ]18 CYP+D 1 𐝕𐝉[ ]𐝁𐝌 ][
# PE1: U-KA-RE-A-SE-SI-NA KU-PA-RI VIR+[?] 50[ GRA+PA 26 ¹⁄₂ E-KA[ VIR+[?] 72 GRA+PA 36
#
# Disbursement List with more than one other entity
# Description: List of entities with commodities listed against them preceded by more than 1 other entity
# HT34: DA-JU-TE 𐄁 SI-*516 𐄁 SA-RA₂ 𐄁 MI+JA+KA[ ][ ]¹⁄₃ E 𐄁 GRA 200[ ]E+[ ] 2 𐝅𐝇 QA2+[?]+PU ≈ ¹⁄₆ QA2+[?]+RE ¹⁄₄ MI+JA+I 245 SA+MU+KU 100 PA₃ 70 KI-RO 37 E+KA ¹⁄₁₆ PU ¹⁄₈
# HT90: I-KU-RI-NA SA-RA₂ GRA 20 NI 10 OLE+DI 3 SI-RU-MA-RI-TA₂ GRA 1 NI 1 OLE+MI 1 *304 1
# ZA11b: E-TO-RI *516 𐄁 SA-*301-RI 𐄁 GRA+PA 1[ I-OLIV 1[ ]I-DE[ ]RA 2 KU-PA 𐄁 GRA+PA 3 ][
# KH5: A-DA-KI-SI-KA 𐄁 A-RA-U-DA 𐄁 WI-SA-SA-NE CYP+E 2 VINb+WI 2 WI-NA-DU 𐄁 *301-NA 𐄁 KU-PA-ZU CYP[ 3[ ≈ ¹⁄₆ NI 2 𐝆𐝁
#
# Entity List with another entity
# Description: List of entities with values assigned preceded by 1 other entity
# HT1: QE-RA₂-U 𐄁 KI-RO 197 ZU-SU 70 DI-DI-ZA-KE 52 KU-PA₃-NU 109 A-RA-NA-RE 105
# HT10a: KU-NI-SU 𐄁 SA-MA 4 𐄁 PA 𐄁 DA-RE 16 ¹⁄₂ U-*325-ZA 4 *301 6 U-*325-ZA 14[ *305-RU 2 ¹⁄₂ DA-RI-DA 8 ME-ZA 3
# HT10b: U-TI 1 DA-RE 2 TA-RI-NA 15 *312-TA 6 ¹⁄₂ KA-SA-RU 6 TA-NA-TI 9 ¹⁄₄
# HT15: U-*34-SI GRA DU-AROM-A 684 GRA+L4+L4 570 *188 𐄁 KI-RO 400 ][
# HT16: KA-KU-PA 𐄁 DI-NA-U ¹⁄₈ 𐄁 WA ¹⁄₃ *188+KU ³⁄₈ SA-PO ZE ¹⁄₁₆
# HT20: PA-RO-SU 𐄁 KU-MA-JU ¹⁄₄ QE-KU-RE 𐄁 DI ¹⁄₂ *21M ¹⁄₈ SA-RE-JU ¹⁄₈ WA ¹⁄₄ *188+KU ¹⁄₂
# HT24a: KU-PA₃-RI-JA KI-MA-RU[ ]6 MA-RU-ME 10 ]9 ¹⁄₂ MA-RU-ME 6 PA-SA-RI-JA MA-RU-ME[ RU-I-KO *560[
# HT13: KA-U-DE-TA VIN 𐄁 TE 𐄁 RE-ZA 5[ ¹⁄₂[ TE-TU 56 TE-KI 27 ¹⁄₂ KU-ZU-NI 18 DA-SI-*118 19 I-DU-NE-SI 5 KU-RO 130 ¹⁄₂
# HT104: TA-PA 𐄁 TE+RO[ 𐄁 DA-KU-SE-NE-TI 45 ¹⁄₂ I-DU-TI 20 ¹⁄₂ PA-DA-SU-TI 29 KU-RO 95
# HT115a: *47-NU-RA-JA 𐄁 I 𐄁 GRA+BOSm RI-TA-MA-NU-WI 2 *301-U-RA NA-*21F-NE-MI-NA 1 SE-KU-TU ¹⁄₂ PA-RA-NE 1 A-SE-JA 𐝂𐝂𐝂𐝂 KA-PO-RU 1 RI-SU-MA[ SU 2 ¹⁄₅[ ][
# HT122a: ]RA-RI 𐄁 U-DE-ZA 2[ ]2 DA-SI-*118 2 PA[ 𐄁 ]DI 1 TE-KI 2 QA-*310-I 3 JA-MI-DA-RE 1 SI-DA-RE 1 *324-DI-RA 1 PA-DE 1 KU-PA₃-NU 1 PA-TA-NE 1 *306-TU 1 ]DU 1 KU-PA₃-NU 1 DA-RI-DA 1 KU-RO 31 KU-DA 1
# HT122b: JE-DI 𐄁 *346 𐄁 VIR+[?][ ]*306-KI-TA₂ 7[ ]A-RA-JU-U-DE-ZA 2 QA-QA-RU 2 DI 2 DA-RE 2 KU-RO 65 PO-TO-KU-RO 97
# HT123+124b: *188-*308 11 *312 1 ³⁄₄ TI-DA-TA 𐄁 PI-SA 4 *188 1 *188-DU 𐄁 10 TU-PA-DI-DA 13/20 KA-NA[ ]SI-DU ≈ ¹⁄₆ DU-MA-I-NA ³⁄₈ KU-RO 20 KI-RO 5[
# HT126a: DA-NA-SI 𐄁 *318 𐄁 A-NA[ 𐄁 ]1 U[ ]¹⁄₂ SI-DI-JA 1[ ]U-*49 1 PI[ ]62[ ]2[ ][
# HT7a: QE-TI 𐄁 VIR+[?] I-RU-JA 3 DU-JA 4 TA-NA-TI 1 DA-RE 1 TE-TU 1
# HT7b: *21F-TU-NE 1 DA-RU-*329 2
# HT85b: KI-KI-RA-JA 𐄁 KI-RE-TA₂ 1 QE-KA 1 PA 1 TE-TU[ 1 KA 1 DI 1 ME-ZA 1 RE-DI-SE 1 WA-DU-NI-MI 1 MA-DI 1 QA-*310-I 1
# HT9b: PA₃ 𐄁 WA-JA-PI[ — KA-*305 𐄁 PA-DE 3 A-SI 3 *306-TU 8 *324-DI-RA 2 QE-PU 2 TA-I-AROM 2 DI-NA-U 4 KU-RO 24
# HT94b: KI-RO 𐄁 TU-MA 1 PA-TA-NE 1 DE-DI 1 KE-KI-RU 1 SA-RU 1 KU-RO 5 *86 𐄁 RA[ 𐄁 ]DE-ME-TE 1 *21F-TU[ 𐄁 1
# HT95a: DA-DU-MA-TA 𐄁 GRA DA-ME 10 MI-NU-TE 10 SA-RU 20 KU-NI-SU 10 DI-DE-RU 10 QE-RA₂-U 7
# HT95b: A-DU 𐄁 SA-RU 10 ][ 𐄁 ][ DA-ME 10 MI-NU-TE 10 KU-NI-SU 10 DI-DE-RU 10 QE-RA₂-U 10
# ZA5a: *21F-*118 𐄁 VIN-SU KI-NI-MA 7 O-TA-NI-ZA-SE 6 SA-MI-DA-E[ ][ ][ ][ ][
# ZA15a: *47-KU-NA SA-VIN QE-SI-ZU-E 57 I-TI-NI-SA 10 ME-VIN MI-ZA-SE 3 *28B-NU-MA-RE 6 SI-PI-KI 2 ¹⁄₂ JA-SA-MU 5 SA-MI-DA-E 4 *363-KE-MA-SE 5
#
# Entity List with more than one other entity
# Description: List of entities with values assigned preceded by other entitiesand optional potential transaction sign
# HT117a: MA-KA-RI-TE 𐄁 KI-RO 𐄁 U-MI-NA-SI 𐄁 U-SU 1 MI-TU 1 KU-RA-MU 1 MA-RU 1 KU-PA₃-NU 1 TU-JU-MA 1 U-DI-MI 1 MI-RU-TA-RA-RE 1 TE-JA-RE 1 NA-DA-RE 1 KU-RO 10 — SA-TA 𐄁 KU-KU-DA-RA 1 KO-SA-I-TI 1 DA-MI-NU 1 DA-NE-KU-TI 1 KI-DA-RO 1
# HT17: RA-󽇫-TI 𐄁 TE 𐄁 VIN 37 SA-RO 10 SI-DA-RE 5
# HT26a: *406VAS+KE 𐄁 *312-TE-TE 𐄁 TA-TI 21 MI-KI-SE-NA 15 U-NU-*21F 5[ ][
# HT11b: ]DE-NU RU-RA₂ *86-KA 40 KA 30 KA 50 RU-ZU-NA KA 30 SA-QE-RI 𐄁 KA 30 KU-RO 180
# HT85a: A-DU 𐄁 *307+*387 𐄁 VIR+[?] 𐄁 DA-RI-DA 12 PA₃-NI 12 U-*325-ZA 6 DA-SI-*118 24 KU-ZU-NI 5 TE-KE 3 DA-RE 4 KU-RO[ ]66
# HT87: *21F-TU-NE 𐄁 MA-KA-RI-TE 𐄁 PI-TA-KE-SI 1 JA-RE-MI 1 DI-KI-SE 1 QE-SU-PU 1 KU-RU-KU 1 A-RA[ 𐄁 ]A-TU 1
# HT88: A-DU VIR+KA 20 RE-ZA 6 NI 𐄁 KI-KI-NA 7 KI-RO 𐄁 KU-PA₃-PA₃ 1 KA-JU 1 KU-PA₃-NU 1 PA-JA-RE 1 SA-MA-RO 1 DA-TA-RE 1 KU-RO 6
# HT9a: SA-RO 𐄁 TE 𐄁 VIN 𐄁 PA-DE 𐄁 5 ³⁄₄ *306-TU 10 DI-NA-U 4 QE-PU 2 *324-DI-RA 2 ¹⁄₂ TA-I-AROM 2 ¹⁄₂ A-RU 4 ¹⁄₄ KU-RO 31 ³⁄₄
#
# Entity and Commodity List with another entity
# Description: List of entities and commodities with values assigned preceded by 1 other entityand optional potential transaction sign
# HT19: RA-*164-TI 𐄁 TE 𐄁 VIN 30 SA-RO 5 ¹⁄₂ DU-ME-DI 43 ¹⁄₂
# HT103: U-TA₂ 𐄁 NI 40 PA₃ DA-KU-SE-NE[ ]6 ¹⁄₂ *188 13 DA-KU-NA 1 DA-KU-SE-NE 1 KI-RA 5 ¹⁄₂
# HT110a: SI-DU-*34-KU-MI CYP+E 20 KU-PA 1 KU-RO 100[ ]NI 15[ ]60
# HT26b: 𐄁 *406VAS+KE 𐄁 VIR+[?] 9 ]RO-NI 3 KA-U-ZU-NI 4 KI+MU 12 I-*308 2[ *188-*86 7[ ][
# HT27a: TI-NI-TA 𐄁 *307 𐄁 VIR+[?] 90 ]50 *86 51 RE 20 ]I-MI-SA-RA 43 ]QE 21 KI-DA[ ]KI-*310 𐄁 KU-*305[ ]SA-RA-DI 5 VIR+[?] 42 KU-RO 335 CYP 9 𐝕𐝁 NI 10 ¹⁄₃ VIN 7
# HT36: JE-DI *307+*387-GRA+QE 64 ¹⁄₂ DU-ZU-WA 7 ¹⁄₂ ][ 6
# HT6a: KA-PA 𐄁 DA-TA-RA 𐄁 TE 𐄁 NI 15 PI-TA-JA 24 JA+RU 𐝓 MA-*321 10 O-RA₂-DI-NE 2 KA-PA-QE 5 ³⁄₄ DA-QE-RA 𐄁 QE-PI-TA 22 ³⁄₄ NI 15 ¹⁄₂
# HT6b: WA-DU-NI-MI 3 ≈ ¹⁄₆ RA-TI-SE 1 MA-RI-RE-I 3 DU-DA-MA 66 DA-KI 3 ¹⁄₄ SA-MA 35 PA₃-NI-NA 17 ¹⁄₂
# HT62+73: ]SA-RA 𐄁 TE 𐄁 VIN[ 𐄁 ]NA GRA 15 ¹⁄₄ KA-KU 4[ ]18 *28B-TI[ 𐄁 6 DI[ ]4 ¹⁄₄ KA[ ]VIR+[?][ ]4 KO[ ]NU 17[ ]25[ ][ ]KU[ 𐄁 ]1[ PA-I-KI[ ]8 SA-RO-QE[ ]28 ][ ][
# HT8a: JE-DI OLE+KI 10 PA₃-KA-RA-TI 1 ¹⁄₂ PA 3 ¹⁄₂ TE-*301 2 QA-*310-I ³⁄₄ SI-KI-RA ¹⁄₄ KI-RE-TA-NA ¹⁄₂
# HT89: A-SA-RA₂ 𐄁 *307 𐄁 *305 23 JU+*317+QE 22 MA-I-MI 24 VIR+*313a 13 TA-RA 5 KU-RO 87 CYP 2 ³⁄₄ NI 2 ¹⁄₄ VIN 6[
# HT93a: PA₃-NI-NA 𐄁 GRA-PA₃ 𐄁 RE+SE 12 DI-RI-NA 𐄁 DA+RE+SE 43 ¹⁄₂ KI-DI-NI 5 𐝆𐝅 A-SE 𐄁 I-GRA+PA 26 ³⁄₄ SA-RA₂ 20 QA-QA-RU 𐄁 I-GRA+PA 5 VIR+[?]-I 6 DE-JU-KU 1 ¹⁄₂ O-TI[ 𐄁 3 DA-RI-DA *406-VS 2 *343 2 PA₃-NI-NA[ ]PA-SE-JA 20 VIR+[?] 10 ¹⁄₈[ ]KA 4
# HT97a: KA-RU 𐄁 *307+*387 𐄁 VIR+KA 82 *327 33 KA-NU-TI 25 PA-I-TO 6 DI 4 NA-TI 4 MA-DI 5 JU 15 KI 3 ZU ]5 TA-TI 2 DE[ 𐄁 3[ ]A 5 ][
# ZA8: KI-RA 𐄁 A-TA-RE 𐄁 NI ¹⁄₂ KU-TU-KO-RE double mina A-RI-NI-TA 1[ ? TA-I-NU-MA-PA ¹⁄₂ MA-KA-I-SE 2 𐝃𐝆 DA-I-PI-TA 2 ¹⁄₂ KA-I-RO 4 ?
#
# Entity and Commodity List with more than one other entity
# Description: List of entities and commodities with values assigned preceded by other entitiesand optional potential transaction sign
# ARKH2: SI-DA-TE KU-RA *131B 5 A-SI-DA-TO-I 12 ZU-*301-SE-DE-*21F-*118 6 A-SU-PU-WA 4 RU-MI[ ][
# HT102: KA-PA SA-RA₂ GRA 976 PA₃-NI GRA+PA 33[ ]VIR+[?] GRA+PA 33 DI-RI-NA 10 MA-ZU 3 WI 10 I-KA 5 KU-RO 1060
# HT115b: ]RU 𐄁 PA-RA-NE ¹⁄₂ TI-NU-JA 𐄁 NU-WI 𐄁 GRA ¹⁄₂ DU-PA₃-NA 1 KU-RU-MA 𐄁 I ¹⁄₂ *306-TU-JA 1 A-I[ 1 *306+MI 1 KU-TA[
# HT140: U-*34-SI 𐄁 *86-SI-NI 𐄁 1[ JE-DI 𐄁 OLE+KI 1 ¹⁄₂ 𐄁 U-*34-SI[ 𐄁 *86-SI-*118-KA 3 KA[ ]MA[ ]KA[ ]4 OLE+U 3 KA 1 OLE+U 1 ]KA 1 OLE+U 2 KA-PA ¹⁄₂[ OLE+U 6 ¹⁄₂
# HT6a: KA-PA 𐄁 DA-TA-RA 𐄁 TE 𐄁 NI 15 PI-TA-JA 24 JA+RU 𐝓 MA-*321 10 O-RA₂-DI-NE 2 KA-PA-QE 5 ³⁄₄ DA-QE-RA 𐄁 QE-PI-TA 22 ³⁄₄ NI 15 ¹⁄₂
# HT6b: WA-DU-NI-MI 3 ≈ ¹⁄₆ RA-TI-SE 1 MA-RI-RE-I 3 DU-DA-MA 66 DA-KI 3 ¹⁄₄ SA-MA 35 PA₃-NI-NA 17 ¹⁄₂
# HT86a: A-KA-RU 𐄁 KU-NI-SU GRA+K+L 20 SA-RU 20 DI-DE-RU 20 QA-RA₂-WA 10 — A-DU 𐄁 DA-ME GRA+B 20 MI-NU-TE 20
# HT86b: A-KA-RU 𐄁 KU-NI-SU GRA+K+L 20 SA-RU 20 DI-DE
# HT96a: I-TI-TI-KU-NI 𐄁 A-PA-RA-NE 𐄁 A-AROM-TE 𐄁 SI-MI-TA GRA 5 RU-SA 4 *323-*317 1 PI-TA-RA 𐄁 1 *323-*344 1 — ]KU-MA-RO 𐄁 𐄁 TE-NI 20 ]NI 2 — ][

# %%
# Look for ones in the network that we're missing from our classification.
import os
import json

l = []
in_network = []
inputdir = "../lineara.xyz/network/transactions/final/"
for subdir, dirs, files in os.walk(inputdir):
    for file in files:
        if file[-2:] != "js":
            continue
        json_file = open(subdir + os.sep + file)
        data = json.load(json_file)
        n = data["name"]
        in_network += [n]
        if n not in tablet_detail:
            l+=[n]
print(l)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-60-aee703a9b736> in <module>
#      11             continue
#      12         json_file = open(subdir + os.sep + file)
# ---> 13         data = json.load(json_file)
#      14         n = data["name"]
#      15         in_network += [n]
#
# /usr/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /usr/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 16 column 5 (char 408)

# %%
not_in_network = [t for t in tablet_detail if t not in in_network]
print(not_in_network)
# Out:
# ['ZA14', 'HT127b', 'HT146', 'HT25a', 'HT3', 'HT39', 'HT63', 'HT98a', 'ZA20', 'ZA7a', 'ZA10a', 'ZA10b', 'PE2', 'HT130', 'HT24b', 'TY2', 'HT105', 'HT123+124a', 'HT132', 'HT20', 'ZA1a', 'ZA9', 'ZA15b', 'KH6', 'KH7a', 'KH7b', 'TY3b', 'ARKH5', 'KH4', 'HT31', 'HT43', 'PE1', 'ZA11b', 'HT16', 'HT24a', 'HT123+124b', 'HT7b', 'HT26a', 'HT11b', 'HT103', 'HT110a', 'HT26b', 'HT36', 'HT62+73', 'HT89', 'HT93a', 'HT140', 'HT86b']
